# %%
import pandas as pd
from googletrans import Translator

# %% [markdown]
# ### 1. Olvasd be a szeged.csv fájlt. Nézd meg az első pár sorát, a teljes adatbázis méretét, irasd ki a leíro statisztikákat és a korrelációt az oszlopok között.

# %%
df = pd.read_csv('szeged.csv')
df.head(10)
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
# 5  2006-04-01 05:00:00.000 +0200  Partly Cloudy        rain         9.222222
# 6  2006-04-01 06:00:00.000 +0200  Partly Cloudy        rain         7.733333
# 7  2006-04-01 07:00:00.000 +0200  Partly Cloudy        rain         8.772222
# 8  2006-04-01 08:00:00.000 +0200  Partly Cloudy        rain        10.822222
# 9  2006-04-01 09:00:00.000 +0200  Partly Cloudy        rain        13.772222
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
# 5                  7.111111      0.85            13.9587
# 6                  5.522222      0.95            12.3648
# 7                  6.527778      0.89            14.1519
# 8                 10.822222      0.82            11.3183
# 9                 13.772222      0.72            12.5258
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# 1                   259.0          15.8263         0.0               1015.63
# 2                   204.0          14.9569         0.0               1015.94
# 3                   269.0          15.8263         0.0               1016.41
# 4                   259.0          15.8263         0.0               1016.51
# 5                   258.0          14.9569         0.0               1016.66
# 6                   259.0           9.9820         0.0               1016.72
# 7                   260.0           9.9820         0.0               1016.84
# 8                   259.0           9.9820         0.0               1017.37
# 9                   279.0           9.9820         0.0               1017.22
#
#                        Daily Summary
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.
# 2  Partly cloudy throughout the day.
# 3  Partly cloudy throughout the day.
# 4  Partly cloudy throughout the day.
# 5  Partly cloudy throughout the day.
# 6  Partly cloudy throughout the day.
# 7  Partly cloudy throughout the day.
# 8  Partly cloudy throughout the day.
# 9  Partly cloudy throughout the day.

# %%
df.shape
# Out:
# (96453, 12)

# %%
df.describe()
# Out:
#        Temperature (C)  Apparent Temperature (C)      Humidity  \
# count     96453.000000              96453.000000  96453.000000
# mean         11.932678                 10.855029      0.734899
# std           9.551546                 10.696847      0.195473
# min         -21.822222                -27.716667      0.000000
# 25%           4.688889                  2.311111      0.600000
# 50%          12.000000                 12.000000      0.780000
# 75%          18.838889                 18.838889      0.890000
# max          39.905556                 39.344444      1.000000
#
#        Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# count       96453.000000            96453.000000     96453.000000     96453.0
# mean           10.810640              187.509232        10.347325         0.0
# std             6.913571              107.383428         4.192123         0.0
# min             0.000000                0.000000         0.000000         0.0
# 25%             5.828200              116.000000         8.339800         0.0
# 50%             9.965900              180.000000        10.046400         0.0
# 75%            14.135800              290.000000        14.812000         0.0
# max            63.852600              359.000000        16.100000         0.0
#
#        Pressure (millibars)
# count          96453.000000
# mean            1003.235956
# std              116.969906
# min                0.000000
# 25%             1011.900000
# 50%             1016.450000
# 75%             1021.090000
# max             1046.380000

# %%
df.corr()
# Out:
#                           Temperature (C)  Apparent Temperature (C)  Humidity  \
# Temperature (C)                  1.000000                  0.992629 -0.632255
# Apparent Temperature (C)         0.992629                  1.000000 -0.602571
# Humidity                        -0.632255                 -0.602571  1.000000
# Wind Speed (km/h)                0.008957                 -0.056650 -0.224951
# Wind Bearing (degrees)           0.029988                  0.029031  0.000735
# Visibility (km)                  0.392847                  0.381718 -0.369173
# Loud Cover                            NaN                       NaN       NaN
# Pressure (millibars)            -0.005447                 -0.000219  0.005454
#
#                           Wind Speed (km/h)  Wind Bearing (degrees)  \
# Temperature (C)                    0.008957                0.029988
# Apparent Temperature (C)          -0.056650                0.029031
# Humidity                          -0.224951                0.000735
# Wind Speed (km/h)                  1.000000                0.103822
# Wind Bearing (degrees)             0.103822                1.000000
# Visibility (km)                    0.100749                0.047594
# Loud Cover                              NaN                     NaN
# Pressure (millibars)              -0.049263               -0.011651
#
#                           Visibility (km)  Loud Cover  Pressure (millibars)
# Temperature (C)                  0.392847         NaN             -0.005447
# Apparent Temperature (C)         0.381718         NaN             -0.000219
# Humidity                        -0.369173         NaN              0.005454
# Wind Speed (km/h)                0.100749         NaN             -0.049263
# Wind Bearing (degrees)           0.047594         NaN             -0.011651
# Visibility (km)                  1.000000         NaN              0.059818
# Loud Cover                            NaN         NaN                   NaN
# Pressure (millibars)             0.059818         NaN              1.000000

# %% [markdown]
# ### 2. Töröld a "Loud Cover" és "Daily Summary" oszlopokat. Nevezd át a maradék oszlopokat úgy, hogy mindegyik kisbetűs, magyar és _-al legyenek elválasztva szavak

# %%
df.drop(['Loud Cover','Daily Summary'], axis=1, inplace=True)
df.columns.str.lower()
df['Hungarian'] = df['English'].apply(translator.translate, src='en', dest='hu').apply(getattr, args=('text',))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'English'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# C:\Users\STARSC~1\AppData\Local\Temp/ipykernel_16664/650737096.py in <module>
#       1 df.drop(['Loud Cover','Daily Summary'], axis=1, inplace=True)
#       2 df.columns.str.lower()
# ----> 3 df['Hungarian'] = df['English'].apply(translator.translate, src='en', dest='hu').apply(getattr, args=('text',))
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'English'

# %%
df.rename(columns=dict(zip(df.columns, 
                           ['formázott_dátum', 'összegzés', 'csapadék', 'hőmérséklet_c', 
                            'hőérzet_c', 'páratartalom', 'szélsebesség_km/h', 
                            'szélirány_fok', 'láthatóság_km', 'légnyomás_mbar'])), 
          inplace=True)

# %% [markdown]
# ### 3. Nézd meg melyik napon vol a legnagyobb a láthatóság? Mi volt az átlagos páratartalom? Melyik nap volt a legnagyobb különbség a hőmérséklet és a hőérzet között?

# %%
df['láthatóság_km'].max()
# Out:
# 16.1

# %%
df['páratartalom'].mean()
# Out:
# 0.7348989663358906

# %%
(df['hőmérséklet_c'] - df['hőérzet_c']).max()
# Out:
# 10.183333333333337

# %% [markdown]
# ### 4. Hány olyan sor van ahol hó esett, a leírás alapján ködös idő volt és vagy 0 és 20 méter között volt a láthatóság vagy 3.2 km felett volt a láthatóság, de a páratartalom 0.9 alatt volt?

# %%
condition = ((df['csapadék'] == 'snow') &
            (df['összegzés'] == 'Foggy') &
            ((df['láthatóság_km'] <= 0.2) |
             (df['láthatóság_km'] >=3.2)) &
            (df['páratartalom'] <= 0.9))
len(df.loc[condition])
# Out:
# 12

# %%
df.loc[condition]
# Out:
#                      formázott_dátum összegzés csapadék  hőmérséklet_c  \
# 29338  2009-01-14 10:00:00.000 +0100     Foggy     snow      -1.027778
# 29876  2009-01-06 20:00:00.000 +0100     Foggy     snow      -8.888889
# 38376  2010-01-25 00:00:00.000 +0100     Foggy     snow     -11.561111
# 38378  2010-01-25 02:00:00.000 +0100     Foggy     snow     -12.177778
# 38379  2010-01-25 03:00:00.000 +0100     Foggy     snow     -11.694444
# 50645  2011-11-18 06:00:00.000 +0100     Foggy     snow      -6.205556
# 55153  2012-02-22 01:00:00.000 +0100     Foggy     snow      -6.150000
# 55154  2012-02-22 02:00:00.000 +0100     Foggy     snow      -7.777778
# 55157  2012-02-22 05:00:00.000 +0100     Foggy     snow      -8.888889
# 55158  2012-02-22 06:00:00.000 +0100     Foggy     snow      -8.888889
# 56069  2012-01-30 05:00:00.000 +0100     Foggy     snow      -6.111111
# 56072  2012-01-30 08:00:00.000 +0100     Foggy     snow      -7.222222
#
#        hőérzet_c  páratartalom  szélsebesség_km/h  szélirány_fok  \
# 29338  -5.116667          0.88            12.3970           50.0
# 29876  -8.888889          0.84             0.0000            0.0
# 38376 -11.561111          0.88             3.0107           12.0
# 38378 -12.177778          0.88             3.2200           10.0
# 38379 -11.694444          0.88             3.2200           20.0
# 50645  -6.205556          0.89             3.0429          185.0
# 55153  -6.150000          0.89             2.6565          208.0
# 55154  -7.777778          0.88             3.2200          200.0
# 55157  -8.888889          0.84             3.2200          200.0
# 55158  -8.888889          0.84             3.2200          200.0
# 56069  -6.111111          0.88             0.0000            0.0
# 56072  -7.222222          0.88             0.0000            0.0
#
#        láthatóság_km  légnyomás_mbar
# 29338         3.2039         1017.70
# 29876         0.1610         1024.30
# 38376         0.1610         1035.37
# 38378         0.1610         1035.68
# 38379         0.1610         1035.87
# 50645         0.0161         1028.16
# 55153         0.1610         1034.06
# 55154         0.1610         1034.10
# 55157         0.1610         1033.70
# 55158         0.1610         1033.60
# 56069         0.1610         1032.50
# 56072         0.1610         1033.00
